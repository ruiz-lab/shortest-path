# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

#     fig = plt.figure(figsize=(15, 42))
#     columns = 1
#     rows = 14
#     for i in range(1, 14 +1):
#         img = mpimg.imread(filenames[i-1])
#         print(img.shape)
#         fig.add_subplot(rows, columns, i)
#         plt.imshow(img)
#         plt.title(titles[i-1])
#         plt.axis('off')
#         #if img.shape[1] == 432:
#             #plt.figure(figsize=(530-75-20,470-55-10))
#     plt.tight_layout()
#     plt.savefig(string+'original.png')
#     plt.show()

# %%
train_index = (range(240)[::3])
val_index = (range(240)[1::3])
test_index = (range(240)[2::3])

def showFig(dir):
    if dir != 'k=1':
        scales = [1000,100,10,1,1/10,1/100,0]
        graph_sizes = [30,30,30,30,30,10,20,40,80,160]
        probabilities = [0.05,0.1,0.2,0.4,0.8,0.15,0.15,0.15,0.15,0.15]
        for i in range(len(scales)):
            for j in range(len(graph_sizes)):
                if scales[i] == 10:
                    pos = i*10+j
                    print(scales[i], graph_sizes[j], probabilities[j])
                    fig = plt.figure(figsize=(15, 30))
                    img = mpimg.imread(dir+'/'+str(train_index[pos])+'.png')
                    fig.add_subplot(1, 3, 1)
                    plt.imshow(img)
                    plt.axis('off')
                    img = mpimg.imread(dir+'/'+str(val_index[pos])+'.png')
                    fig.add_subplot(1, 3, 2)
                    plt.imshow(img)
                    plt.axis('off')
                    img = mpimg.imread(dir+'/'+str(test_index[pos])+'.png')
                    fig.add_subplot(1, 3, 3)
                    plt.imshow(img)
                    plt.axis('off')
                    plt.tight_layout()
                    #plt.savefig(string+'original.png')
                    plt.show()
    else:
        scales = [1000,100,10,1,1/10,1/100,0]
        graph_sizes = [30,30,30,30,30,10,20,40,80,160]
        probabilities = [0.05,0.1,0.2,0.4,0.8,0.15,0.15,0.15,0.15,0.15]
        for i in range(1):
            for j in range(len(graph_sizes)):
                pos = i*10+j
                print(scales[i], graph_sizes[j], probabilities[j])
                fig = plt.figure(figsize=(15, 30))
                img = mpimg.imread(dir+'/'+str(train_index[pos])+'.png')
                fig.add_subplot(1, 3, 1)
                plt.imshow(img)
                plt.axis('off')
                img = mpimg.imread(dir+'/'+str(val_index[pos])+'.png')
                fig.add_subplot(1, 3, 2)
                plt.imshow(img)
                plt.axis('off')
                img = mpimg.imread(dir+'/'+str(test_index[pos])+'.png')
                fig.add_subplot(1, 3, 3)
                plt.imshow(img)
                plt.axis('off')
                plt.tight_layout()
                #plt.savefig(string+'original.png')
                plt.show()

        scales = [1000,100,10,1,1/10,1/100,0]
        graph_sizes = [30,30,30,30,30,10,20,40,80]
        probabilities = [0.05,0.1,0.2,0.4,0.8,0.15,0.15,0.15,0.15]
        for i in range(1,len(scales)):
            for j in range(len(graph_sizes)):
                pos = 10+(i-1)*9+j
                #print(pos)
                print(scales[i], graph_sizes[j], probabilities[j])
                fig = plt.figure(figsize=(15, 30))
                img = mpimg.imread(dir+'/'+str(train_index[pos])+'.png')
                fig.add_subplot(1, 3, 1)
                plt.imshow(img)
                plt.axis('off')
                img = mpimg.imread(dir+'/'+str(val_index[pos])+'.png')
                fig.add_subplot(1, 3, 2)
                plt.imshow(img)
                plt.axis('off')
                img = mpimg.imread(dir+'/'+str(test_index[pos])+'.png')
                fig.add_subplot(1, 3, 3)
                plt.imshow(img)
                plt.axis('off')
                plt.tight_layout()
                #plt.savefig(string+'original.png')
                plt.show()
            pos = 63+i
            #print(pos)
            print(scales[i], 160, 0.15)
            fig = plt.figure(figsize=(15, 30))
            img = mpimg.imread(dir+'/'+str(train_index[pos])+'.png')
            fig.add_subplot(1, 3, 1)
            plt.imshow(img)
            plt.axis('off')
            img = mpimg.imread(dir+'/'+str(val_index[pos])+'.png')
            fig.add_subplot(1, 3, 2)
            plt.imshow(img)
            plt.axis('off')
            img = mpimg.imread(dir+'/'+str(test_index[pos])+'.png')
            fig.add_subplot(1, 3, 3)
            plt.imshow(img)
            plt.axis('off')
            plt.tight_layout()
            #plt.savefig(string+'original.png')
            plt.show()

# %%
showFig('1 seed set')
# Out:
# 10 30 0.05
# 10 30 0.1
# 10 30 0.2
# 10 30 0.4
# 10 30 0.8
# 10 10 0.15
# 10 20 0.15
# 10 40 0.15
# 10 80 0.15
# 10 160 0.15
